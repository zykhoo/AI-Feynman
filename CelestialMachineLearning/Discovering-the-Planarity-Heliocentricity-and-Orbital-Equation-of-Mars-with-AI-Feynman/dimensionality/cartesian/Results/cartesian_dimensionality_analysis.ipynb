# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def replace_equations(input_string):
  input_string = input_string.replace("exp", "np.exp")
  input_string = input_string.replace("sqrt", "np.sqrt")
  input_string = input_string.replace("pi", "np.pi")
  input_string = input_string.replace("log", "np.log")
  input_string = input_string.replace("sin", "np.sin")
  input_string = input_string.replace("anp.sin", "np.arcsin")
  input_string = input_string.replace("cos", "np.cos")
  input_string = input_string.replace("anp.cos", "np.arccos")
  input_string = input_string.replace("tan", "np.tan")
  input_string = input_string.replace("anp.tan", "np.arctan")
  return input_string

# %% [markdown]
# # Cartesian

# %%
cat /content/drive/MyDrive/mars/iiWAS2023/dimensionality/cartesian/Results/1dim-cartesian2.txt
# Out:
# 30.600413967060202 4.9353809136708175 3602.828066979697 0.0 30.59832794974783 0
# 26.243185028090252 4.714563462851561 3441.631327881639 3.0 26.255785686242028 1.50000000000000
# 26.18974742745799 4.713625043559762 3440.9462817986264 4.0 26.238712830583562 pi/2
# 26.286136128595988 4.711910919637633 3439.694971335472 6.266786540694901 26.20755607498595 1.42857142857143
# 26.27548819411559 4.711539375333826 3439.4237439936933 47.016264764097436 26.20080758402638 1.42333122851664
# 25.97429597495936 4.699298422950437 3430.487848753819 47.15691825249024 25.979439909334168 acos(0.0581143163144588*x0)
# 25.800716579156944 4.691300679462576 3424.6494960076807 49.63878591681517 25.835818398314665 tan(0.0171195974445658*x1 + 1)
# 24.251832868239738 4.591872295432275 3352.0667756655603 54.87210651085564 24.115223825599376 1.221198383854+((0+1)/((((x0+1)+1)+1)+1))

# %%
import pandas as pd
df = pd.DataFrame(columns=["equation", "fit", "parsimony", "colour"])

# %%
with open("/content/drive/MyDrive/mars/iiWAS2023/dimensionality/cartesian/Results/1dim-cartesian2.txt", "r") as file:
  data = file.readlines()
  count=0
  for j in data:
    count+=1
    equations = j.split(' ',5)
    equation = equations[-1]
    fit = equations[0]
    parsimony = equations[-3]
    equation = replace_equations(equation.replace("\n", ""))
    if ("x0" in equation)|("x1" in equation)|("x2" in equation)|("x3" in equation)|("x4" in equation)|("x5" in equation):
      equation = equation.replace("x0","\lambda_{M1}")
      equation = equation.replace("x1","\lambda_{S1}")
      print("Equation %s: %s, %s, %s" %(count, equation, fit, parsimony))
      entry = pd.DataFrame.from_dict({"equation": [equation], "fit": [float(fit)], "parsimony": [float(parsimony)], "colour": ["red"]})
      df = pd.concat([df, entry], ignore_index=True)
# Out:
# Equation 6: np.arccos(0.0581143163144588*\lambda_{M1}), 25.97429597495936, 47.15691825249024
# Equation 7: np.tan(0.0171195974445658*\lambda_{S1} + 1), 25.800716579156944, 49.63878591681517
# Equation 8: 1.221198383854+((0+1)/((((\lambda_{M1}+1)+1)+1)+1)), 24.251832868239738, 54.87210651085564

# %%
with open("/content/drive/MyDrive/mars/iiWAS2023/dimensionality/cartesian/Results/2dim-cartesian2.txt", "r") as file:
  data = file.readlines()
  count=0
  for j in data:
    count+=1
    equations = j.split(' ',5)
    equation = equations[-1]
    fit = equations[0]
    parsimony = equations[-3]
    equation = replace_equations(equation.replace("\n", ""))
    if ("x0" in equation)|("x1" in equation)|("x2" in equation)|("x3" in equation)|("x4" in equation)|("x5" in equation):
      equation = equation.replace("x0","\lambda_{M1}")
      equation = equation.replace("x1","\lambda_{M2}")
      equation = equation.replace("x2","\lambda_{S1}")
      equation = equation.replace("x3","\lambda_{S2}")
      print("Equation %s: %s, %s, %s" %(count, equation, fit, parsimony))
      entry = pd.DataFrame.from_dict({"equation": [equation], "fit": [float(fit)], "parsimony": [float(parsimony)], "colour": ["blue"]})
      df = pd.concat([df, entry], ignore_index=True)
# Out:
# Equation 6: np.arccos(-0.1*\lambda_{S2}), 25.64483542835924, 12.321928094887362
# Equation 7: np.arccos(-0.0994685481205907*\lambda_{S2}), 25.646337793234743, 51.177377557334395
# Equation 8: 1.221468928502+((0+1)/((((\lambda_{M1}+1)+1)+1)+1)), 24.193629954515547, 54.87242609053939
# Equation 9: 0.4*\lambda_{M1}**2 - 0.428571428571429*\lambda_{M1}*\lambda_{S1} - 0.666666666666667*\lambda_{M1}*\lambda_{S2} + 0.4*\lambda_{M2}**2 - 0.7*\lambda_{M2}*\lambda_{S1} + 0.4*\lambda_{M2}*\lambda_{S2} + 0.4*\lambda_{S1}**2 + 0.4*\lambda_{S2}**2 + 0.584193269507273, 24.197671746802534, 109.90502196981836
# Equation 10: -0.0416098292506629*\lambda_{M1}**2 - 0.0337764400695433*\lambda_{M1} - 0.0526409552168828*\lambda_{M2}**2 + 1.66666666666667, 24.01500545828219, 144.74802921037372
# Equation 11: (-0.017832447865237*\lambda_{M1}**2 - 0.0122546126831841*\lambda_{M1} - 0.0197336507795308*\lambda_{M2}**2 - 0.00525510104504469*\lambda_{M2} + 1.28929406165126)**2, 22.88886308949539, 223.87092914623554
# Equation 12: (-0.017832447865237*\lambda_{M1}**2 - 0.000833616276921385*\lambda_{M1}*\lambda_{M2} - 0.0122546126831841*\lambda_{M1} - 0.0197336507795308*\lambda_{M2}**2 - 0.00525510104504469*\lambda_{M2} + 1.28929406165126)**2, 22.852385781451215, 260.1495935425966
# Equation 13: (0.618804692832026*\lambda_{M1}**2 - 0.63643067097383*\lambda_{M1}*\lambda_{S1} - 1.06306011300215*\lambda_{M1}*\lambda_{S2} - 0.104724154100595*\lambda_{M1} + 0.613759226153589*\lambda_{M2}**2 - \lambda_{M2}*\lambda_{S1} + 0.632982631682707*\lambda_{M2}*\lambda_{S2} + 0.629510568181755*\lambda_{S1}**2 + 0.612538055894269*\lambda_{S2}**2 + 0.111425533671115*\lambda_{S2} + 0.871191849870558)**0.5, 22.85790054281851, 487.7946744713231
# Equation 14: (0.618804692832026*\lambda_{M1}**2 - 0.63643067097383*\lambda_{M1}*\lambda_{S1} - 1.06306011300215*\lambda_{M1}*\lambda_{S2} - 0.104724154100595*\lambda_{M1} + 0.613759226153589*\lambda_{M2}**2 - 1.05609058819238*\lambda_{M2}*\lambda_{S1} + 0.632982631682707*\lambda_{M2}*\lambda_{S2} + 0.0355913865390322*\lambda_{M2} + 0.629510568181755*\lambda_{S1}**2 + 0.612538055894269*\lambda_{S2}**2 + 0.111425533671115*\lambda_{S2} + 0.871191849870558)**0.5, 21.965074873744786, 575.0750666655597
# Equation 15: (0.618804692832026*\lambda_{M1}**2 - 0.63643067097383*\lambda_{M1}*\lambda_{S1} - 1.06306011300215*\lambda_{M1}*\lambda_{S2} - 0.104724154100595*\lambda_{M1} + 0.613759226153589*\lambda_{M2}**2 - 1.05609058819238*\lambda_{M2}*\lambda_{S1} + 0.632982631682707*\lambda_{M2}*\lambda_{S2} + 0.0355913865390322*\lambda_{M2} + 0.629510568181755*\lambda_{S1}**2 + 0.0223685214839701*\lambda_{S1} + 0.612538055894269*\lambda_{S2}**2 + 0.111425533671115*\lambda_{S2} + 0.871191849870558)**0.5, 20.64729804447814, 616.0996737044031
# Equation 16: (0.618804692832026*\lambda_{M1}**2 - 0.63643067097383*\lambda_{M1}*\lambda_{S1} - 1.06306011300215*\lambda_{M1}*\lambda_{S2} - 0.104724154100595*\lambda_{M1} + 0.613759226153589*\lambda_{M2}**2 - 1.05609058819238*\lambda_{M2}*\lambda_{S1} + 0.632982631682707*\lambda_{M2}*\lambda_{S2} + 0.0355913865390322*\lambda_{M2} + 0.629510568181755*\lambda_{S1}**2 + 0.00362394983019903*\lambda_{S1}*\lambda_{S2} + 0.0223685214839701*\lambda_{S1} + 0.612538055894269*\lambda_{S2}**2 + 0.111425533671115*\lambda_{S2} + 0.871191849870558)**0.5, 20.646411859740734, 654.4984457310802

# %%
with open("/content/drive/MyDrive/mars/iiWAS2023/dimensionality/cartesian/Results/3dim-cartesian2.txt", "r") as file:
  data = file.readlines()
  count=0
  for j in data:
    count+=1
    equations = j.split(' ',5)
    equation = equations[-1]
    fit = equations[0]
    parsimony = equations[-3]
    equation = replace_equations(equation.replace("\n", ""))
    if ("x0" in equation)|("x1" in equation)|("x2" in equation)|("x3" in equation)|("x4" in equation)|("x5" in equation):
      equation = equation.replace("x0","\lambda_{M1}")
      equation = equation.replace("x1","\lambda_{M2}")
      equation = equation.replace("x2","\lambda_{M3}")
      equation = equation.replace("x3","\lambda_{S1}")
      equation = equation.replace("x4","\lambda_{S2}")
      equation = equation.replace("x5","\lambda_{S3}")
      print("Equation %s: %s, %s, %s" %(count, equation, fit, parsimony))
      entry = pd.DataFrame.from_dict({"equation": [equation], "fit": [float(fit)], "parsimony": [float(parsimony)], "colour": ["green"]})
      df = pd.concat([df, entry], ignore_index=True)
# Out:
# Equation 6: 2*\lambda_{M3} + 1.5, 26.174923313419647, 9.339850002884624
# Equation 7: 3*\lambda_{M3} + 1.5, 26.135226423779915, 9.754887502163468
# Equation 8: np.arccos(-0.1*\lambda_{S2}), 25.740253627707702, 12.321928094887362
# Equation 9: np.arccos(-0.0976600194525864*\lambda_{S2}), 25.701796200232803, 51.15090520398956
# Equation 10: 2*\lambda_{M3} + 1.563343180129, 25.6227384023779, 53.4914778402431
# Equation 11: 3*\lambda_{M3} + 1.554202964751, 25.20412832969766, 53.89805574946688
# Equation 12: 1.221364981489+((0+1)/((((\lambda_{M1}+1)+1)+1)+1)), 24.227454072797002, 54.872303311958625
# Equation 13: (-0.122779553443767*\lambda_{M1}**2 - 0.0813081718681856*\lambda_{M1} - 0.162459305130141*\lambda_{M2}**2 + 2.7769713723898)**0.5, 24.027927597389294, 195.01288777871025
# Equation 14: (-0.122779553443767*\lambda_{M1}**2 - 0.0813081718681856*\lambda_{M1} - 0.162459305130141*\lambda_{M2}**2 - 0.0553745589642152*\lambda_{M2} + 2.7769713723898)**0.5, 23.211063452867165, 237.34524822059421
# Equation 15: (-0.122779553443767*\lambda_{M1}**2 - 0.00143238266999229*\lambda_{M1}*\lambda_{M2} - 0.0813081718681856*\lambda_{M1} - 0.162459305130141*\lambda_{M2}**2 - 0.0553745589642152*\lambda_{M2} + 2.7769713723898)**0.5, 23.208773524316015, 274.4048742334576
# Equation 16: np.arccos(0.090616012160451*\lambda_{M1} - 0.0319600776983129*\lambda_{M2} - 0.0232047508907192*\lambda_{S1} + 0.0283550675125619*\lambda_{S2}**2 - 0.0976600194525864*\lambda_{S2} + 0.0289977987855869*(\lambda_{M3} - \lambda_{S1} + \lambda_{S3})**2 + 0.0307948365787156), 21.327212728113828, 335.2860964230674
# Equation 17: np.arccos(0.090616012160451*\lambda_{M1} - 0.0319600776983129*\lambda_{M2} - 0.0232047508907192*\lambda_{S1} + 0.0283550675125619*\lambda_{S2}**2 - 0.0976600194525864*\lambda_{S2} + 0.0232047508907192*\lambda_{S3} + 0.0289977987855869*(\lambda_{M3} - \lambda_{S1} + \lambda_{S3})**2 + 0.0307948365787156), 21.322971451465044, 376.3636537715853
# Equation 18: (0.629054488675243*\lambda_{M1}**2 - 1.09702641151907*\lambda_{M1}*\lambda_{S2} + 0.66380215388438*\lambda_{M1}*(\lambda_{M3} - \lambda_{S1} + \lambda_{S3}) - 0.0970587695214965*\lambda_{M1} + 0.615404209188107*\lambda_{M2}**2 + 0.612460120314694*\lambda_{M2}*\lambda_{S2} + 1.07475058070276*\lambda_{M2}*(\lambda_{M3} - \lambda_{S1} + \lambda_{S3}) + 0.0353178541225072*\lambda_{M2} - 0.025256019547904*\lambda_{M3} + 0.025256019547904*\lambda_{S1} + 0.64348326795563*\lambda_{S2}**2 - \lambda_{S2}*(0.0454680776226979*\lambda_{M3} - 0.0454680776226979*\lambda_{S1} + 0.0454680776226979*\lambda_{S3}) + 0.0969507210012649*\lambda_{S2} + 0.639899761292375*(\lambda_{M3} - \lambda_{S1} + \lambda_{S3})**2 + 0.868658496424638)**0.5, 21.291878819377377, 796.718222170258
# Equation 19: (0.629054488675243*\lambda_{M1}**2 + 0.66380215388438*\lambda_{M1}*((\lambda_{M3}+\lambda_{S3})-\lambda_{S1}) - 1.09702641151907*\lambda_{M1}*\lambda_{S2} - 0.0970587695214965*\lambda_{M1} + 0.615404209188107*\lambda_{M2}**2 + 1.07475058070276*\lambda_{M2}*((\lambda_{M3}+\lambda_{S3})-\lambda_{S1}) + 0.612460120314694*\lambda_{M2}*\lambda_{S2} + 0.0353178541225072*\lambda_{M2} + 0.639899761292375*((\lambda_{M3}+\lambda_{S3})-\lambda_{S1})**2 - 0.0454680776226979*((\lambda_{M3}+\lambda_{S3})-\lambda_{S1})*\lambda_{S2} - 0.025256019547904*((\lambda_{M3}+\lambda_{S3})-\lambda_{S1}) + 0.64348326795563*\lambda_{S2}**2 + 0.0969507210012649*\lambda_{S2} + 0.868658496424638)**0.5, 21.291049607608088, 837.9179865913017

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter( df[df["colour"]=="red"]["fit"].values,df[df["colour"]=="red"]["parsimony"].values, color = "red", label = "1dim")
plt.scatter(df[df["colour"]=="blue"]["fit"].values,df[df["colour"]=="blue"]["parsimony"].values, color = "blue", label = "2dim")
plt.scatter(df[df["colour"]=="green"]["fit"].values,df[df["colour"]=="green"]["parsimony"].values, color = "green", label = "3dim")
plt.legend()

# %%
# !pip install paretoset
# Out:
# Collecting paretoset
#   Downloading paretoset-1.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from paretoset) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from paretoset) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->paretoset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->paretoset) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->paretoset) (1.16.0)
# Installing collected packages: paretoset
# Successfully installed paretoset-1.2.3

# %%
from paretoset import paretoset
mask = paretoset(df[["fit","parsimony"]], sense=["min", "min"])
paretoset_df = df[mask]

# %%
df[["fit","parsimony","colour"]][mask].sort_values("parsimony")
# Out:
#           fit   parsimony colour
# 14  26.174923    9.339850  green
# 15  26.135226    9.754888  green
# 3   25.644835   12.321928   blue
# 18  25.622738   53.491478  green
# 19  25.204128   53.898056  green
# 2   24.251833   54.872107    red
# 20  24.227454   54.872303  green
# 5   24.193630   54.872426   blue
# 7   24.015005  144.748029   blue
# 8   22.888863  223.870929   blue
# 9   22.852386  260.149594   blue
# 24  21.327213  335.286096  green
# 25  21.322971  376.363654  green
# 12  20.647298  616.099674   blue
# 13  20.646412  654.498446   blue

# %%
pd.set_option('display.float_format', lambda x: '%.2e' % x)
df[mask].sort_values("parsimony").values
# Out:
# array([['2*\\lambda_{M3} + 1.5', 26.174923313419647, 9.339850002884624,
#         'green'],
#        ['3*\\lambda_{M3} + 1.5', 26.135226423779915, 9.754887502163468,
#         'green'],
#        ['np.arccos(-0.1*\\lambda_{S2})', 25.64483542835924,
#         12.321928094887362, 'blue'],
#        ['2*\\lambda_{M3} + 1.563343180129', 25.6227384023779,
#         53.4914778402431, 'green'],
#        ['3*\\lambda_{M3} + 1.554202964751', 25.20412832969766,
#         53.89805574946688, 'green'],
#        ['1.221198383854+((0+1)/((((\\lambda_{M1}+1)+1)+1)+1))',
#         24.251832868239738, 54.87210651085564, 'red'],
#        ['1.221364981489+((0+1)/((((\\lambda_{M1}+1)+1)+1)+1))',
#         24.227454072797002, 54.872303311958625, 'green'],
#        ['1.221468928502+((0+1)/((((\\lambda_{M1}+1)+1)+1)+1))',
#         24.193629954515547, 54.87242609053939, 'blue'],
#        ['-0.0416098292506629*\\lambda_{M1}**2 - 0.0337764400695433*\\lambda_{M1} - 0.0526409552168828*\\lambda_{M2}**2 + 1.66666666666667',
#         24.01500545828219, 144.74802921037372, 'blue'],
#        ['(-0.017832447865237*\\lambda_{M1}**2 - 0.0122546126831841*\\lambda_{M1} - 0.0197336507795308*\\lambda_{M2}**2 - 0.00525510104504469*\\lambda_{M2} + 1.28929406165126)**2',
#         22.88886308949539, 223.87092914623554, 'blue'],
#        ['(-0.017832447865237*\\lambda_{M1}**2 - 0.000833616276921385*\\lambda_{M1}*\\lambda_{M2} - 0.0122546126831841*\\lambda_{M1} - 0.0197336507795308*\\lambda_{M2}**2 - 0.00525510104504469*\\lambda_{M2} + 1.28929406165126)**2',
#         22.852385781451215, 260.1495935425966, 'blue'],
#        ['np.arccos(0.090616012160451*\\lambda_{M1} - 0.0319600776983129*\\lambda_{M2} - 0.0232047508907192*\\lambda_{S1} + 0.0283550675125619*\\lambda_{S2}**2 - 0.0976600194525864*\\lambda_{S2} + 0.0289977987855869*(\\lambda_{M3} - \\lambda_{S1} + \\lambda_{S3})**2 + 0.0307948365787156)',
#         21.327212728113828, 335.2860964230674, 'green'],
#        ['np.arccos(0.090616012160451*\\lambda_{M1} - 0.0319600776983129*\\lambda_{M2} - 0.0232047508907192*\\lambda_{S1} + 0.0283550675125619*\\lambda_{S2}**2 - 0.0976600194525864*\\lambda_{S2} + 0.0232047508907192*\\lambda_{S3} + 0.0289977987855869*(\\lambda_{M3} - \\lambda_{S1} + \\lambda_{S3})**2 + 0.0307948365787156)',
#         21.322971451465044, 376.3636537715853, 'green'],
#        ['(0.618804692832026*\\lambda_{M1}**2 - 0.63643067097383*\\lambda_{M1}*\\lambda_{S1} - 1.06306011300215*\\lambda_{M1}*\\lambda_{S2} - 0.104724154100595*\\lambda_{M1} + 0.613759226153589*\\lambda_{M2}**2 - 1.05609058819238*\\lambda_{M2}*\\lambda_{S1} + 0.632982631682707*\\lambda_{M2}*\\lambda_{S2} + 0.0355913865390322*\\lambda_{M2} + 0.629510568181755*\\lambda_{S1}**2 + 0.0223685214839701*\\lambda_{S1} + 0.612538055894269*\\lambda_{S2}**2 + 0.111425533671115*\\lambda_{S2} + 0.871191849870558)**0.5',
#         20.64729804447814, 616.0996737044031, 'blue'],
#        ['(0.618804692832026*\\lambda_{M1}**2 - 0.63643067097383*\\lambda_{M1}*\\lambda_{S1} - 1.06306011300215*\\lambda_{M1}*\\lambda_{S2} - 0.104724154100595*\\lambda_{M1} + 0.613759226153589*\\lambda_{M2}**2 - 1.05609058819238*\\lambda_{M2}*\\lambda_{S1} + 0.632982631682707*\\lambda_{M2}*\\lambda_{S2} + 0.0355913865390322*\\lambda_{M2} + 0.629510568181755*\\lambda_{S1}**2 + 0.00362394983019903*\\lambda_{S1}*\\lambda_{S2} + 0.0223685214839701*\\lambda_{S1} + 0.612538055894269*\\lambda_{S2}**2 + 0.111425533671115*\\lambda_{S2} + 0.871191849870558)**0.5',
#         20.646411859740734, 654.4984457310802, 'blue']], dtype=object)
